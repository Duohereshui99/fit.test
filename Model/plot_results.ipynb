# %%
import numpy as np
import matplotlib.pyplot as plt


Sys=['211Po','213Rn','215Ra','217Th','219U']
Z=[84,86,88,90,92]
T_half_expt=[0.516,19.36e-3,1.68e-3,254e-6,60e-6]
T_half_calc=[0.5114632567634809,0.019125018415904648,0.0016754569638269573,0.0002532844695462757,6.0554072181574916e-05]
T_half_2sigma=[0.006100941734231333,0.00037538084911566534,1.9609032394723824e-05,4.070240801237136e-06,6.9356006982034776e-06]


# 计算比值和误差
ratios = [calc/expt for calc, expt in zip(T_half_calc, T_half_expt)]
ratio_errors = [2*sigma/expt for sigma, expt in zip(T_half_2sigma, T_half_expt)]

# 创建图形
plt.figure(figsize=(12, 6))

# 绘制比值点
for z, ratio, sys in zip(Z, ratios, Sys):
    plt.plot(z, ratio, 'o', markersize=8, label=f'{sys}')

# 绘制误差棒
plt.errorbar(Z, ratios, yerr=ratio_errors, fmt='none', 
             ecolor='black', elinewidth=2, capsize=5)

# 添加参考线
plt.axhline(y=1, color='gray', linestyle='--', linewidth=1)

# 设置坐标轴
plt.xticks(Z, [f"{z}({sys})" for z, sys in zip(Z, Sys)], fontsize=10)
plt.xlabel('Z', fontsize=12)
plt.ylabel('Theoretical/Experimental Ratio', fontsize=12)
plt.ylim(0.77,1.25)  # 自动调整y轴范围

# 添加图例和网格
plt.legend(fontsize=10, loc='upper left')
plt.grid(True, which="both", ls="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %%
print(np.exp(800))
# Out:
# inf
# C:\Users\16437\AppData\Local\Temp\ipykernel_42612\1378869140.py:1: RuntimeWarning: overflow encountered in exp
#   print(np.exp(800))
